# %%
import re
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                         'Chrome/117.0.0.0 Safari/537.36'}
url = 'https://www.cvonline.lt/lt/search?limit=20&offset=0&categories%5B0%5D=INFORMATION_TECHNOLOGY&keywords%5B0%5D=data%20engineer&towns%5B0%5D=540&fuzzy=true&suitableForRefugees=false&isHourlySalary=false&isRemoteWork=false&isQuickApply=false'
print(url)
# Out:
# https://www.cvonline.lt/lt/search?limit=20&offset=0&categories%5B0%5D=INFORMATION_TECHNOLOGY&keywords%5B0%5D=data%20engineer&towns%5B0%5D=540&fuzzy=true&suitableForRefugees=false&isHourlySalary=false&isRemoteWork=false&isQuickApply=false

# %%
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
jobs = soup.findAll('li', class_='jsx-1871295890 jsx-78775730 vacancies-list__item false')

# %%
print(jobs)
# Out:
# [<li class="jsx-1871295890 jsx-78775730 vacancies-list__item false"><div class="jsx-3024910437"><a class="jsx-3024910437 vacancy-item" href="/lt/vacancy/1091993/wix-com-uab/qa-automation-engineer-wix-blog" rel="noopener noreferrer" target="_self"><div class="jsx-3024910437 vacancy-item__logo hide-mobile"><img alt="Wix.com, UAB" class="jsx-3024910437" src="/api/v1/files-service/1b384855-67dd-48dd-abff-1e5e5f14f014"/></div><div class="jsx-3024910437 vacancy-item__info"><div class="jsx-3024910437 vacancy-item__main"><div class="jsx-3024910437"><span class="jsx-3024910437 vacancy-item__title">QA Automation Engineer - Wix Blog</span><span class="jsx-3024910437 hide-desktop hide-mobile" id="vacancyViews">248</span><div class="jsx-3024910437 vacancy-item__body"><div class="jsx-3024910437 vacancy-item__column"><a href="/lt/search/employer/wix-com-uab?employerId=36122&amp;employerName=Wix.com,%20UAB">Wix.com, UAB</a></div><div class="jsx-3024910437 vacancy-item__column vacancy-item__locations
# ...

# %%
for job in jobs[:1]:
    url = job.find('a', class_='jsx-3024910437').get('href', None)

    title = job.find('span', class_='jsx-3024910437 vacancy-item__title').text
    company = job.find('div', class_='jsx-3024910437 vacancy-item__column').text
    region = job.find('div', class_='jsx-3024910437 vacancy-item__column vacancy-item__locations').text
    salary = job.find('span', class_='jsx-3024910437 vacancy-item__salary-label').text
# Out:
# € 2500 – 5000 Vilnius, Vilniaus apskritis, Lietuva
